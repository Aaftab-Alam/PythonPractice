# %%
import pandas as pd
df=pd.read_csv('first_pd.csv')

# %%
df
# Out:
#                     Username                    NAME           ERP ID
# 0     0201csml129@niet.co.in         Nirbhay Shukla       0201csml129
# 1          raja342@gmail.com                    Raja  0201ece032@niet
# 2     0201csio021@niet.co.in      Shiv Shikhar Sinha      0201CSIO021
# 3    jain.palak535@gmail.com              Palak Jain      0201mcsd004
# 4      0201cse164@niet.co.in  Shashank  Singh Parmar       0201cse164
# ..                       ...                     ...              ...
# 116   0201csml013@niet.co.in             Aditi Gupta      0201csml013
# 117   0201csml054@niet.co.in           Yash sonkhiya      0201csml054
# 118    0201ite149@niet.co.in             Vivek Gupta       0201ite149
# 119    anishane555@gmail.com        Aniket Shishodia      0201CSML031
# 120   0201csds095@niet.co.in         sulekha chaubey      0201csds095
#
# [121 rows x 3 columns]

# %%
print(df['Username'].head(120))
# Out:
# 0       0201csml129@niet.co.in
# 1            raja342@gmail.com
# 2       0201csio021@niet.co.in
# 3      jain.palak535@gmail.com
# 4        0201cse164@niet.co.in
#                 ...
# 115     0201csds052@niet.co.in
# 116     0201csml013@niet.co.in
# 117     0201csml054@niet.co.in
# 118      0201ite149@niet.co.in
# 119      anishane555@gmail.com
# Name: Username, Length: 120, dtype: object

# %%
df.tail(6)
# Out:
#                    Username              NAME       ERP ID
# 115  0201csds052@niet.co.in      Komal Bharti  0201csds052
# 116  0201csml013@niet.co.in       Aditi Gupta  0201csml013
# 117  0201csml054@niet.co.in     Yash sonkhiya  0201csml054
# 118   0201ite149@niet.co.in       Vivek Gupta   0201ite149
# 119   anishane555@gmail.com  Aniket Shishodia  0201CSML031
# 120  0201csds095@niet.co.in   sulekha chaubey  0201csds095

# %%
df.tail(50)
# Out:
#                                 Username               NAME  \
# 71                  0201cs027@niet.co.in        Dilip Kumar
# 72                  0201CS041@niet.co.in       Chirag Singh
# 73                guptsnehajio@gmail.com        Sneha Gupta
# 74           tanyagangwar16501@gmail.com       Ritu Gangwar
# 75             amitjaiswal8666@gmail.com       Amit jaiswal
# 76          nehasingh.june2000@gmail.com        Neha Singh
# 77                 0201cse137@niet.co.in        Harsh Gupta
# 78              pushkarjha4433@gmail.com       Pushkar jha
# 79             aakashsingh3536@gmail.com        AAKASH DEEP
# 80             aditiaastha4291@gmail.com       Aditi Aastha
# 81           aadarshrajput9808@gmail.com     Adarsh Chauhan
# 82                   atulhts11@gmail.com     Atul Agnihotri
# 83                 0201CSE138@niet.co.in     Abhishek gupta
# 84               rajayadav4693@gmail.com          Raja babu
# 85                    hrsh0412@gmail.com       harsh sharma
# ...

# %%
df.tail(120)
# Out:
#                     Username                    NAME           ERP ID
# 1          raja342@gmail.com                    Raja  0201ece032@niet
# 2     0201csio021@niet.co.in      Shiv Shikhar Sinha      0201CSIO021
# 3    jain.palak535@gmail.com              Palak Jain      0201mcsd004
# 4      0201cse164@niet.co.in  Shashank  Singh Parmar       0201cse164
# 5       dakshaagg1@gmail.com          daksha agrawal       0201cse254
# ..                       ...                     ...              ...
# 116   0201csml013@niet.co.in             Aditi Gupta      0201csml013
# 117   0201csml054@niet.co.in           Yash sonkhiya      0201csml054
# 118    0201ite149@niet.co.in             Vivek Gupta       0201ite149
# 119    anishane555@gmail.com        Aniket Shishodia      0201CSML031
# 120   0201csds095@niet.co.in         sulekha chaubey      0201csds095
#
# [120 rows x 3 columns]

# %%
df.ndim
# Out:
# 2
